# %% [markdown]
# #### My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <blockquote>Advait Santosh Chavale</blockquote>
# My current occupation is 'Student' and my desired occupation 'Data Scientist'

# %% [markdown]
# <i>I am interested in data-science due to curosity, I want to find hidden stories behind data which stay unheard </i>

# %% [markdown]
# ### My code below will show beautiful addtion of two spicy numbers

# %%
print(1*2+2)
4

# %% [markdown]
# --- Languages and libraries
# <ol>
# <li>Python</li>
# <li>Scala</li>
# <li>HTML</li>
# <li>R</li>
# </ol>
# <ol>
#     <li>Scikit</li>
#     <li>Pandas</li>
# </ol>
# **I suggest observor to see 'IBM Watson Studio' is down since too long, Please cheeck at your end  <a href="https://cloud.ibm.com/" >IBM Watson Studio</a>
# I Tried more than once
# |Date|Time|Success| |-----|-------|------| |July12,2020|10.30pmIST|N| |July21,2020|09.00amIST|N|
#
# #### For refrence purpose, please find below image
# <img src="data:image/png;base64,..." style="max-width:100%">

# %% [markdown]
# This is a Numbered List\n\nHere is a Sample Markdown Table ->\n\n| Name  | Address | Salary |\n|-------|---------|--------|\n| Stacy | Sydney  | 500
